# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

MODEL_PATH = "runs/segment/train/weights/best.pt"

IMG_PATH = "../test_images/test45.jpg"

model = YOLO(MODEL_PATH)
results = model.predict(IMG_PATH, imgsz=1024, conf=0.25)

results[0].show()
# Out:
# image 1/1 e:\plate_det\notebooks\..\test_images\test45.jpg: 768x1024 1 license_plate, 66.7ms
# Speed: 7.6ms preprocess, 66.7ms inference, 4.7ms postprocess per image at shape (1, 3, 768, 1024)
