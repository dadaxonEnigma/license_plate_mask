# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

MODEL_PATH = "runs/segment/train/weights/best.pt"

IMG_PATH = "../test_images/name_plate/i.webp"

model = YOLO(MODEL_PATH)
results = model.predict(IMG_PATH, imgsz=1024, conf=0.5)

results[0].show()
# Out:
# image 1/1 e:\plate_det\notebooks\..\test_images\name_plate\i.webp: 1024x864 1 license_plate, 348.5ms
# Speed: 146.4ms preprocess, 348.5ms inference, 579.8ms postprocess per image at shape (1, 3, 1024, 864)
