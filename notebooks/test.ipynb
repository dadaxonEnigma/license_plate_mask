# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

MODEL_PATH = "runs/segment/train/weights/best (4).pt"

IMG_PATH = "../test_images/new_cars/hqdefault.jpg"

model = YOLO(MODEL_PATH)
results = model.predict(IMG_PATH, imgsz=1024, conf=0.5)

results[0].show()
# Out:
# image 1/1 e:\plate_det\notebooks\..\test_images\new_cars\hqdefault.jpg: 768x1024 1 license_plate, 25.8ms
# Speed: 6.5ms preprocess, 25.8ms inference, 3.3ms postprocess per image at shape (1, 3, 768, 1024)
